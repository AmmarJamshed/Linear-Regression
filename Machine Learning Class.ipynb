# %% [markdown]
# # How to Use MACHINE LEARNING ALGORITHMS SUCH AS LINEAR REGRESSION TO MAKE BASIC PREDICTIONS

# %% [markdown]
# BY Muhammad Ammar Jamshed

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
dfh = pd.read_excel(r'C:\Users\muham\Downloads\Hour Price Prediction.csv.xlsx')

# %%
dfh.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  OpenPorchSF  \
# 0         706        150          856  ...           0           61
# 1         978        284         1262  ...         298            0
# 2         486        434          920  ...           0           42
# 3         216        540          756  ...           0           35
# 4         655        490         1145  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
dfh.drop(['Id'],axis=1, inplace=True) # we use in place to drop the whole column

# %%
x = dfh.drop(['SalePrice'],axis=1)

# %%
y = dfh['SalePrice']

# %%
from sklearn.model_selection import train_test_split
# Seperate test and training data
Tx, Tex, Ty, Tey = train_test_split(x, y, test_size=0.4, random_state=0)

# %%
# import linear Regression 
from sklearn.linear_model import LinearRegression

# %%
ModelLR = LinearRegression()

# %%
ModelLR = ModelLR.fit(Tx, Ty)

# %%
ModelLR.intercept_
# Out:
# 184357.84634249104

# %%
ModelLR.coef_
# Out:
# array([-1.60784695e+02,  4.50879380e-01,  1.78122314e+04,  4.20363560e+03,
#         3.25161918e+02,  1.44932892e+02,  1.80923122e+01,  9.98391098e-01,
#         2.29406190e+01,  1.42205536e+01,  2.14961866e+01,  3.32372726e+01,
#         2.75407013e+03,  1.57027313e+03, -2.37363943e+02, -1.00743403e+04,
#        -1.26704543e+04,  5.22927427e+03,  3.39930215e+03,  3.06737259e+02,
#         3.03217598e+01,  2.35399859e+01,  3.05438878e+00, -8.39089102e+00,
#         1.94959048e+01,  3.11462375e+01,  2.34550624e+01, -1.01344261e+00,
#        -1.20541907e+02, -5.88299124e+02])

# %%
# Predict with test data only
ModelLR.predict(Tex)
# Out:
# array([ 2.55071670e+05,  1.56671932e+05,  9.80376116e+04,  2.27598979e+05,
#         9.76393144e+04,  9.39747268e+04,  2.56847368e+05,  1.45457990e+05,
#         5.14480587e+05,  1.47565429e+05,  1.86506441e+05,  1.52729576e+05,
#         2.44934386e+05,  1.13751542e+05,  1.37557803e+05,  1.48243169e+05,
#         2.36721083e+05,  1.01192491e+05,  1.33466118e+05,  1.79781439e+05,
#         1.24086030e+05,  1.49399209e+05,  9.92316228e+04,  1.60191537e+05,
#         1.94047155e+05,  1.99859838e+05,  1.49732532e+05,  4.06726568e+04,
#         3.12612731e+05,  1.24881144e+05,  1.60295903e+05,  2.15479722e+05,
#         1.54242559e+05,  2.86872693e+05,  2.91342791e+05,  2.02068821e+05,
#         2.71953367e+05,  1.09934862e+05,  2.32246750e+05,  3.26869321e+05,
#         2.15879338e+05,  1.14730181e+05,  1.94071373e+05,  2.92157105e+05,
#         3.16544711e+05,  1.29845916e+05,  1.25797623e+05,  1.18456192e+05,
# ...

# %%
prediction = ModelLR.predict(Tex)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
r2_score(prediction, Tey)
# Out:
# 0.7323156117279219

# %%
mean_absolute_error(prediction, Tey)
# Out:
# 21315.384443599516

# %%
mean_squared_error(prediction, Tey)
# Out:
# 1576006726.538537

# %%
# all errors have their intervals under which the values should ideally lie within 
# in order for the model to be reliable to apply on any business seting

# %%
# For logistic regression ML model

# %%
#same as Above with few changes

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

# %%
modelLogR = LinearRegression()

# %%
modelLogR.fit(Tx,Ty)
# Out:
# LinearRegression()

# %%
predictLinR = ModelLR.predict(Tex)

# %%
predictLinR
# Out:
# array([ 2.55071670e+05,  1.56671932e+05,  9.80376116e+04,  2.27598979e+05,
#         9.76393144e+04,  9.39747268e+04,  2.56847368e+05,  1.45457990e+05,
#         5.14480587e+05,  1.47565429e+05,  1.86506441e+05,  1.52729576e+05,
#         2.44934386e+05,  1.13751542e+05,  1.37557803e+05,  1.48243169e+05,
#         2.36721083e+05,  1.01192491e+05,  1.33466118e+05,  1.79781439e+05,
#         1.24086030e+05,  1.49399209e+05,  9.92316228e+04,  1.60191537e+05,
#         1.94047155e+05,  1.99859838e+05,  1.49732532e+05,  4.06726568e+04,
#         3.12612731e+05,  1.24881144e+05,  1.60295903e+05,  2.15479722e+05,
#         1.54242559e+05,  2.86872693e+05,  2.91342791e+05,  2.02068821e+05,
#         2.71953367e+05,  1.09934862e+05,  2.32246750e+05,  3.26869321e+05,
#         2.15879338e+05,  1.14730181e+05,  1.94071373e+05,  2.92157105e+05,
#         3.16544711e+05,  1.29845916e+05,  1.25797623e+05,  1.18456192e+05,
# ...

# %%
#accuracy ca be wrong thus
from sklearn import metrics

# %%
metrics.mean_absolute_error(predictLinR, Tey)
# Out:
# 21315.384443599516

# %%
metrics.r2_score(predictLinR, Tey)
# Out:
# 0.7323156117279219

# %%
Tey
# Out:
# 529     200624
# 491     133000
# 459     110000
# 279     192000
# 655      88000
#          ...
# 1001     86000
# 453     210000
# 110     136900
# 1189    189000
# 1240    224900
# Name: SalePrice, Length: 584, dtype: int64

# %%
Tex
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 529           20    32668            6            3       1957          1975
# 491           50     9490            6            7       1941          1950
# 459           50     7015            5            4       1950          1950
# 279           60    10005            7            5       1977          1977
# 655          160     1680            6            5       1971          1971
# ...          ...      ...          ...          ...        ...           ...
# 1001          30     5400            5            6       1920          1950
# 453           60     9000            8            5       2008          2008
# 110           50     9525            6            4       1954          1972
# 1189          60     7500            7            5       1999          1999
# 1240          60     8158            7            5       2003          2003
#
# ...

# %%
Tx
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 1169          60    35760           10            5       1995          1996
# 1146          20    11200            6            5       1985          1985
# 503           20    15602            7            8       1959          1997
# 1449         180     1533            5            7       1970          1970
# 1063          30     6000            6            6       1925          1980
# ...          ...      ...          ...          ...        ...           ...
# 763           60     9430            8            5       1999          1999
# 835           20     9600            4            7       1950          1995
# 1216          90     8930            6            5       1978          1978
# 559          120     3196            7            5       2003          2004
# 684           60    16770            7            5       1998          1998
#
# ...

# %%
Ty
# Out:
# 1169    625000
# 1146    180000
# 503     289000
# 1449     92000
# 1063    110500
#          ...
# 763     337000
# 835     128000
# 1216    112000
# 559     234000
# 684     221000
# Name: SalePrice, Length: 876, dtype: int64
